# %%
import pandas as pd

# %matplotlib inline

# %%
df = pd.read_csv('bookkeeper_task_variation.csv', skipinitialspace=True)
#print df
df.plot(kind='line',x=['Tasks'],y=['Memory(MB)','Time(secs)'],title='Memory consumption + Time to create dict (pipelines=1, stage per pipeline=1)')

# %%
df = pd.read_csv('bookkeeper_stage_variation.csv', skipinitialspace=True)
#print df
df.plot(kind='line',x=['Stages'],y=['Memory(MB)','Time(secs)'],title='Memory consumption + Time to create dict (pipelines=1, tasks per stage per pipeline=1)')

# %%
df = pd.read_csv('bookkeeper_pipeline_variation.csv', skipinitialspace=True)
#print df
df.plot(kind='line',x=['Pipelines'],y=['Memory(MB)','Time(secs)'],title='Memory consumption + Time to create dict (stages per pipeline=1, tasks per stage per pipeline=1)')
