# %% [markdown]
# # How to run this
# ```
# virtualenv /tmp/bm --system-site-packages
# . /tmp/bm/bin/activate
# ipython notebook --matplotlib
# ```

# %%
#brewer2mpl makes it easier to use color tables from colorbrewer2.org in matplotlib
# !pip install brewer2mpl
# Out:
# Downloading/unpacking brewer2mpl
#   Downloading brewer2mpl-1.4.1-py2.py3-none-any.whl
# Installing collected packages: brewer2mpl
# Successfully installed brewer2mpl
# Cleaning up...

# %%
# %matplotlib inline 
from urllib import urlopen

import brewer2mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set up some better defaults for matplotlib
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = brewer2mpl.get_map('Dark2', 'Qualitative', 7).mpl_colors

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
def gen_plot(data, cores = [1,2,4,8]):
    red, blue = '#B2182B', '#2166AC'
    
    idx = 0
    for c in cores:
        idx = idx + 1
        dslice = data[data.cores == c]
        dslice.reset_index(inplace=True) 
        
        plt.subplot("22{0}".format(idx))
        plt.subplots_adjust(hspace=0.5)  
        plt.bar(dslice.index, dslice.sim_1_finished, color=red, label='Simulation')
        plt.bar(dslice.index, dslice.ana_1_finished, bottom=dslice.sim_1_finished, color=blue, label='Analysis')
        plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5], dslice.instances, rotation='horizontal')
        plt.ylabel("Runtime (seconds)")
        plt.xlabel("Instances")
        plt.title("{0} Core(s)".format(c))
        plt.legend(loc='upper left')
        remove_border()

# %%
file = open('./sim_ana_zero_workload_results_local.csv')
data = pd.read_csv(file,  sep=',')
gen_plot(data)

# %%
file = open('./sim_ana_60sec_workload_results_local.csv')
data = pd.read_csv(file,  sep=',')
gen_plot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-71bce3d2a5ed> in <module>()
#       1 file = open('./sim_ana_60sec_workload_results_local.csv')
# ----> 2 data = pd.read_csv(file,  sep=',')
#       3 gen_plot(data)
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /Library/Python/2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# /Library/Python/2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4797)()
#
# ValueError: No columns to parse from file
